# %% [markdown]
# <h1 style="text-align: center;">OpenSidewalkMap Statistics</h1>

# %%
import networkx as nx
import osmnx as ox

# %matplotlib inline
ox.__version__
# Out:
# '1.2.1'

# %%
G = ox.graph_from_place("Curitiba", 
# network_type="walk",
custom_filter='["highway"~"footway"]',
retain_all=True,
)
fig, ax = ox.plot_graph(G)

# %%
# !jupyter nbconvert --to html optimized_route_osmnx.ipynb
# Out:
# [NbConvertApp] Converting notebook optimized_route_osmnx.ipynb to html
# [NbConvertApp] Writing 639641 bytes to optimized_route_osmnx.html
